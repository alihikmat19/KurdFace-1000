# %%
# !pip install keras==2.15 tensorflow==2.15 tensorflow_addons
# Out:
# /usr/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Requirement already satisfied: keras==2.15 in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: tensorflow==2.15 in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (2.15.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (2.13.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.15) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15) (3.2.2)

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow_addons as tfa
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
tf.random.set_global_generator(tf.random.Generator.from_seed(seed=42))
tf.random.set_seed(42)
tf.keras.utils.set_random_seed(42)
tf.config.experimental.enable_op_determinism()

# %%
df = pd.read_excel('/kaggle/input/local-beauty/Dataset.xlsx')
df['image name'] = '/kaggle/input/local-beauty/all images/all images/'+df['image name']

df_train, df_test = train_test_split(df, test_size=0.2, random_state=42, stratify=df['gender']) # 30% of data go to df_test
df_test, df_valid = train_test_split(df_test, test_size=0.5, random_state=42, stratify=df_test['gender']) # 15% valid and 15% testing

# %%
def load_data(im_path, label_score, label_gender, label_smile):
    image = tf.io.read_file(im_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [384, 384])
    return image, (label_score, label_gender, label_smile)


def create_dataset(df):
    im_paths = df['image name'].values.astype('str')
    labels_score = df['final rating'].values.astype('float32')
    labels_gender = df['gender'].values.astype('float32')
    labels_smile = df['Smile - non Smile'].values.astype('float32')
    dataset = tf.data.Dataset.from_tensor_slices((im_paths, labels_score, labels_gender, labels_smile))
    dataset = dataset.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
    return  dataset

train_dataset = create_dataset(df_train)
valid_dataset = create_dataset(df_valid)
test_dataset = create_dataset(df_test)

batch_size=32
train_dataset = train_dataset.shuffle(1024).batch(batch_size).prefetch(tf.data.AUTOTUNE)
valid_dataset = valid_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
input_layer = layers.Input((384,384,3))
x = layers.RandomFlip(mode="horizontal")(input_layer)
model = tf.keras.applications.EfficientNetV2B0( 
    include_top=False,
    weights="imagenet",
    input_tensor = x, # x input_layer
    pooling='avg'
)

act='relu' # swish relu elu
x = layers.Dense(64, activation=act)(model.output)
x = layers.Dense(32, activation=act)(x)
x = layers.Dense(1, activation='sigmoid')(x)
output1 = layers.Lambda(lambda x: x*4+1, name='Score')(x)

x = layers.Dense(64, activation=act)(model.output)
x = layers.Dense(32, activation=act)(x)
output2 = layers.Dense(2, activation='softmax', name='gender')(x)


x = layers.Dense(64, activation=act)(model.output)
x = layers.Dense(32, activation=act)(x)
output3 = layers.Dense(2, activation='softmax', name='smile')(x)



model = Model(model.input, [output1, output2, output3])

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 384, 384, 3)]        0         []
#
#  random_flip_2 (RandomFlip)  (None, 384, 384, 3)          0         ['input_3[0][0]']
#
#  rescaling_2 (Rescaling)     (None, 384, 384, 3)          0         ['random_flip_2[0][0]']
#
#  normalization_2 (Normaliza  (None, 384, 384, 3)          0         ['rescaling_2[0][0]']
#  tion)
#
#  stem_conv (Conv2D)          (None, 192, 192, 32)         864       ['normalization_2[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 192, 192, 32)         128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 192, 192, 32)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_project_conv (Conv  (None, 192, 192, 16)         4608      ['stem_activation[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 192, 192, 16)         64        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1a_project_activation  (None, 192, 192, 16)         0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  block2a_expand_conv (Conv2  (None, 96, 96, 64)           9216      ['block1a_project_activation[0
#  D)                                                                 ][0]']
#
#  block2a_expand_bn (BatchNo  (None, 96, 96, 64)           256       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 96, 96, 64)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_project_conv (Conv  (None, 96, 96, 32)           2048      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2a_project_bn (BatchN  (None, 96, 96, 32)           128       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 96, 96, 128)          36864     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 96, 96, 128)          512       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 96, 96, 128)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_project_conv (Conv  (None, 96, 96, 32)           4096      ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2b_project_bn (BatchN  (None, 96, 96, 32)           128       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 96, 96, 32)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 96, 96, 32)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 48, 48, 128)          36864     ['block2b_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 48, 48, 128)          512       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 48, 48, 128)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_project_conv (Conv  (None, 48, 48, 48)           6144      ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3a_project_bn (BatchN  (None, 48, 48, 48)           192       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 48, 48, 192)          82944     ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 48, 48, 192)          768       ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 48, 48, 192)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_project_conv (Conv  (None, 48, 48, 48)           9216      ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3b_project_bn (BatchN  (None, 48, 48, 48)           192       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 48, 48, 48)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 48, 48, 48)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 48, 48, 192)          9216      ['block3b_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 48, 48, 192)          768       ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 48, 48, 192)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv2 (Depthwise  (None, 24, 24, 192)          1728      ['block4a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4a_bn (BatchNormaliza  (None, 24, 24, 192)          768       ['block4a_dwconv2[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 24, 24, 192)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 192)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 12)             2316      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 192)            2496      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 24, 24, 192)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 24, 24, 96)           18432     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 24, 24, 96)           384       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 24, 24, 384)          36864     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 24, 24, 384)          1536      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 24, 24, 384)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv2 (Depthwise  (None, 24, 24, 384)          3456      ['block4b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4b_bn (BatchNormaliza  (None, 24, 24, 384)          1536      ['block4b_dwconv2[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 24, 24, 384)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 384)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 384)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 24)             9240      ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 384)            9600      ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 24, 24, 384)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 24, 24, 96)           36864     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 24, 24, 96)           384       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 24, 24, 96)           0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 24, 24, 96)           0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 24, 24, 384)          36864     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 24, 24, 384)          1536      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 24, 24, 384)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv2 (Depthwise  (None, 24, 24, 384)          3456      ['block4c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4c_bn (BatchNormaliza  (None, 24, 24, 384)          1536      ['block4c_dwconv2[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 24, 24, 384)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 384)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 384)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 24)             9240      ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 384)            9600      ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 24, 24, 384)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 24, 24, 96)           36864     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 24, 24, 96)           384       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 24, 24, 96)           0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 24, 24, 96)           0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block5a_expand_conv (Conv2  (None, 24, 24, 576)          55296     ['block4c_add[0][0]']
#  D)
#
#  block5a_expand_bn (BatchNo  (None, 24, 24, 576)          2304      ['block5a_expand_conv[0][0]']
#  rmalization)
#
#  block5a_expand_activation   (None, 24, 24, 576)          0         ['block5a_expand_bn[0][0]']
#  (Activation)
#
#  block5a_dwconv2 (Depthwise  (None, 24, 24, 576)          5184      ['block5a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5a_bn (BatchNormaliza  (None, 24, 24, 576)          2304      ['block5a_dwconv2[0][0]']
#  tion)
#
#  block5a_activation (Activa  (None, 24, 24, 576)          0         ['block5a_bn[0][0]']
#  tion)
#
#  block5a_se_squeeze (Global  (None, 576)                  0         ['block5a_activation[0][0]']
#  AveragePooling2D)
#
#  block5a_se_reshape (Reshap  (None, 1, 1, 576)            0         ['block5a_se_squeeze[0][0]']
#  e)
#
#  block5a_se_reduce (Conv2D)  (None, 1, 1, 24)             13848     ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)  (None, 1, 1, 576)            14400     ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multipl  (None, 24, 24, 576)          0         ['block5a_activation[0][0]',
#  y)                                                                  'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv  (None, 24, 24, 112)          64512     ['block5a_se_excite[0][0]']
#  2D)
#
#  block5a_project_bn (BatchN  (None, 24, 24, 112)          448       ['block5a_project_conv[0][0]']
#  ormalization)
#
#  block5b_expand_conv (Conv2  (None, 24, 24, 672)          75264     ['block5a_project_bn[0][0]']
#  D)
#
#  block5b_expand_bn (BatchNo  (None, 24, 24, 672)          2688      ['block5b_expand_conv[0][0]']
#  rmalization)
#
#  block5b_expand_activation   (None, 24, 24, 672)          0         ['block5b_expand_bn[0][0]']
#  (Activation)
#
#  block5b_dwconv2 (Depthwise  (None, 24, 24, 672)          6048      ['block5b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5b_bn (BatchNormaliza  (None, 24, 24, 672)          2688      ['block5b_dwconv2[0][0]']
#  tion)
#
#  block5b_activation (Activa  (None, 24, 24, 672)          0         ['block5b_bn[0][0]']
#  tion)
#
#  block5b_se_squeeze (Global  (None, 672)                  0         ['block5b_activation[0][0]']
#  AveragePooling2D)
#
#  block5b_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5b_se_squeeze[0][0]']
#  e)
#
#  block5b_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multipl  (None, 24, 24, 672)          0         ['block5b_activation[0][0]',
#  y)                                                                  'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv  (None, 24, 24, 112)          75264     ['block5b_se_excite[0][0]']
#  2D)
#
#  block5b_project_bn (BatchN  (None, 24, 24, 112)          448       ['block5b_project_conv[0][0]']
#  ormalization)
#
#  block5b_drop (Dropout)      (None, 24, 24, 112)          0         ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)           (None, 24, 24, 112)          0         ['block5b_drop[0][0]',
#                                                                      'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2  (None, 24, 24, 672)          75264     ['block5b_add[0][0]']
#  D)
#
#  block5c_expand_bn (BatchNo  (None, 24, 24, 672)          2688      ['block5c_expand_conv[0][0]']
#  rmalization)
#
#  block5c_expand_activation   (None, 24, 24, 672)          0         ['block5c_expand_bn[0][0]']
#  (Activation)
#
#  block5c_dwconv2 (Depthwise  (None, 24, 24, 672)          6048      ['block5c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5c_bn (BatchNormaliza  (None, 24, 24, 672)          2688      ['block5c_dwconv2[0][0]']
#  tion)
#
#  block5c_activation (Activa  (None, 24, 24, 672)          0         ['block5c_bn[0][0]']
#  tion)
#
#  block5c_se_squeeze (Global  (None, 672)                  0         ['block5c_activation[0][0]']
#  AveragePooling2D)
#
#  block5c_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5c_se_squeeze[0][0]']
#  e)
#
#  block5c_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multipl  (None, 24, 24, 672)          0         ['block5c_activation[0][0]',
#  y)                                                                  'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv  (None, 24, 24, 112)          75264     ['block5c_se_excite[0][0]']
#  2D)
#
#  block5c_project_bn (BatchN  (None, 24, 24, 112)          448       ['block5c_project_conv[0][0]']
#  ormalization)
#
#  block5c_drop (Dropout)      (None, 24, 24, 112)          0         ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)           (None, 24, 24, 112)          0         ['block5c_drop[0][0]',
#                                                                      'block5b_add[0][0]']
#
#  block5d_expand_conv (Conv2  (None, 24, 24, 672)          75264     ['block5c_add[0][0]']
#  D)
#
#  block5d_expand_bn (BatchNo  (None, 24, 24, 672)          2688      ['block5d_expand_conv[0][0]']
#  rmalization)
#
#  block5d_expand_activation   (None, 24, 24, 672)          0         ['block5d_expand_bn[0][0]']
#  (Activation)
#
#  block5d_dwconv2 (Depthwise  (None, 24, 24, 672)          6048      ['block5d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5d_bn (BatchNormaliza  (None, 24, 24, 672)          2688      ['block5d_dwconv2[0][0]']
#  tion)
#
#  block5d_activation (Activa  (None, 24, 24, 672)          0         ['block5d_bn[0][0]']
#  tion)
#
#  block5d_se_squeeze (Global  (None, 672)                  0         ['block5d_activation[0][0]']
#  AveragePooling2D)
#
#  block5d_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5d_se_squeeze[0][0]']
#  e)
#
#  block5d_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5d_se_reshape[0][0]']
#
#  block5d_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5d_se_reduce[0][0]']
#
#  block5d_se_excite (Multipl  (None, 24, 24, 672)          0         ['block5d_activation[0][0]',
#  y)                                                                  'block5d_se_expand[0][0]']
#
#  block5d_project_conv (Conv  (None, 24, 24, 112)          75264     ['block5d_se_excite[0][0]']
#  2D)
#
#  block5d_project_bn (BatchN  (None, 24, 24, 112)          448       ['block5d_project_conv[0][0]']
#  ormalization)
#
#  block5d_drop (Dropout)      (None, 24, 24, 112)          0         ['block5d_project_bn[0][0]']
#
#  block5d_add (Add)           (None, 24, 24, 112)          0         ['block5d_drop[0][0]',
#                                                                      'block5c_add[0][0]']
#
#  block5e_expand_conv (Conv2  (None, 24, 24, 672)          75264     ['block5d_add[0][0]']
#  D)
#
#  block5e_expand_bn (BatchNo  (None, 24, 24, 672)          2688      ['block5e_expand_conv[0][0]']
#  rmalization)
#
#  block5e_expand_activation   (None, 24, 24, 672)          0         ['block5e_expand_bn[0][0]']
#  (Activation)
#
#  block5e_dwconv2 (Depthwise  (None, 24, 24, 672)          6048      ['block5e_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5e_bn (BatchNormaliza  (None, 24, 24, 672)          2688      ['block5e_dwconv2[0][0]']
#  tion)
#
#  block5e_activation (Activa  (None, 24, 24, 672)          0         ['block5e_bn[0][0]']
#  tion)
#
#  block5e_se_squeeze (Global  (None, 672)                  0         ['block5e_activation[0][0]']
#  AveragePooling2D)
#
#  block5e_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5e_se_squeeze[0][0]']
#  e)
#
#  block5e_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5e_se_reshape[0][0]']
#
#  block5e_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5e_se_reduce[0][0]']
#
#  block5e_se_excite (Multipl  (None, 24, 24, 672)          0         ['block5e_activation[0][0]',
#  y)                                                                  'block5e_se_expand[0][0]']
#
#  block5e_project_conv (Conv  (None, 24, 24, 112)          75264     ['block5e_se_excite[0][0]']
#  2D)
#
#  block5e_project_bn (BatchN  (None, 24, 24, 112)          448       ['block5e_project_conv[0][0]']
#  ormalization)
#
#  block5e_drop (Dropout)      (None, 24, 24, 112)          0         ['block5e_project_bn[0][0]']
#
#  block5e_add (Add)           (None, 24, 24, 112)          0         ['block5e_drop[0][0]',
#                                                                      'block5d_add[0][0]']
#
#  block6a_expand_conv (Conv2  (None, 24, 24, 672)          75264     ['block5e_add[0][0]']
#  D)
#
#  block6a_expand_bn (BatchNo  (None, 24, 24, 672)          2688      ['block6a_expand_conv[0][0]']
#  rmalization)
#
#  block6a_expand_activation   (None, 24, 24, 672)          0         ['block6a_expand_bn[0][0]']
#  (Activation)
#
#  block6a_dwconv2 (Depthwise  (None, 12, 12, 672)          6048      ['block6a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6a_bn (BatchNormaliza  (None, 12, 12, 672)          2688      ['block6a_dwconv2[0][0]']
#  tion)
#
#  block6a_activation (Activa  (None, 12, 12, 672)          0         ['block6a_bn[0][0]']
#  tion)
#
#  block6a_se_squeeze (Global  (None, 672)                  0         ['block6a_activation[0][0]']
#  AveragePooling2D)
#
#  block6a_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block6a_se_squeeze[0][0]']
#  e)
#
#  block6a_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block6a_se_reshape[0][0]']
#
#  block6a_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block6a_se_reduce[0][0]']
#
#  block6a_se_excite (Multipl  (None, 12, 12, 672)          0         ['block6a_activation[0][0]',
#  y)                                                                  'block6a_se_expand[0][0]']
#
#  block6a_project_conv (Conv  (None, 12, 12, 192)          129024    ['block6a_se_excite[0][0]']
#  2D)
#
#  block6a_project_bn (BatchN  (None, 12, 12, 192)          768       ['block6a_project_conv[0][0]']
#  ormalization)
#
#  block6b_expand_conv (Conv2  (None, 12, 12, 1152)         221184    ['block6a_project_bn[0][0]']
#  D)
#
#  block6b_expand_bn (BatchNo  (None, 12, 12, 1152)         4608      ['block6b_expand_conv[0][0]']
#  rmalization)
#
#  block6b_expand_activation   (None, 12, 12, 1152)         0         ['block6b_expand_bn[0][0]']
#  (Activation)
#
#  block6b_dwconv2 (Depthwise  (None, 12, 12, 1152)         10368     ['block6b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6b_bn (BatchNormaliza  (None, 12, 12, 1152)         4608      ['block6b_dwconv2[0][0]']
#  tion)
#
#  block6b_activation (Activa  (None, 12, 12, 1152)         0         ['block6b_bn[0][0]']
#  tion)
#
#  block6b_se_squeeze (Global  (None, 1152)                 0         ['block6b_activation[0][0]']
#  AveragePooling2D)
#
#  block6b_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6b_se_squeeze[0][0]']
# ...
#
#  block6f_expand_conv (Conv2  (None, 12, 12, 1152)         221184    ['block6e_add[0][0]']
#  D)
#
#  block6f_expand_bn (BatchNo  (None, 12, 12, 1152)         4608      ['block6f_expand_conv[0][0]']
#  rmalization)
#
#  block6f_expand_activation   (None, 12, 12, 1152)         0         ['block6f_expand_bn[0][0]']
#  (Activation)
#
#  block6f_dwconv2 (Depthwise  (None, 12, 12, 1152)         10368     ['block6f_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6f_bn (BatchNormaliza  (None, 12, 12, 1152)         4608      ['block6f_dwconv2[0][0]']
#  tion)
#
#  block6f_activation (Activa  (None, 12, 12, 1152)         0         ['block6f_bn[0][0]']
#  tion)
#
#  block6f_se_squeeze (Global  (None, 1152)                 0         ['block6f_activation[0][0]']
#  AveragePooling2D)
#
#  block6f_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6f_se_squeeze[0][0]']
#  e)
#
#  block6f_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6f_se_reshape[0][0]']
#
#  block6f_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6f_se_reduce[0][0]']
#
#  block6f_se_excite (Multipl  (None, 12, 12, 1152)         0         ['block6f_activation[0][0]',
#  y)                                                                  'block6f_se_expand[0][0]']
#
#  block6f_project_conv (Conv  (None, 12, 12, 192)          221184    ['block6f_se_excite[0][0]']
#  2D)
#
#  block6f_project_bn (BatchN  (None, 12, 12, 192)          768       ['block6f_project_conv[0][0]']
#  ormalization)
#
#  block6f_drop (Dropout)      (None, 12, 12, 192)          0         ['block6f_project_bn[0][0]']
#
#  block6f_add (Add)           (None, 12, 12, 192)          0         ['block6f_drop[0][0]',
#                                                                      'block6e_add[0][0]']
#
#  block6g_expand_conv (Conv2  (None, 12, 12, 1152)         221184    ['block6f_add[0][0]']
#  D)
#
#  block6g_expand_bn (BatchNo  (None, 12, 12, 1152)         4608      ['block6g_expand_conv[0][0]']
#  rmalization)
#
#  block6g_expand_activation   (None, 12, 12, 1152)         0         ['block6g_expand_bn[0][0]']
#  (Activation)
#
#  block6g_dwconv2 (Depthwise  (None, 12, 12, 1152)         10368     ['block6g_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6g_bn (BatchNormaliza  (None, 12, 12, 1152)         4608      ['block6g_dwconv2[0][0]']
#  tion)
#
#  block6g_activation (Activa  (None, 12, 12, 1152)         0         ['block6g_bn[0][0]']
#  tion)
#
#  block6g_se_squeeze (Global  (None, 1152)                 0         ['block6g_activation[0][0]']
#  AveragePooling2D)
#
#  block6g_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6g_se_squeeze[0][0]']
#  e)
#
#  block6g_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6g_se_reshape[0][0]']
#
#  block6g_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6g_se_reduce[0][0]']
#
#  block6g_se_excite (Multipl  (None, 12, 12, 1152)         0         ['block6g_activation[0][0]',
#  y)                                                                  'block6g_se_expand[0][0]']
#
#  block6g_project_conv (Conv  (None, 12, 12, 192)          221184    ['block6g_se_excite[0][0]']
#  2D)
#
#  block6g_project_bn (BatchN  (None, 12, 12, 192)          768       ['block6g_project_conv[0][0]']
#  ormalization)
#
#  block6g_drop (Dropout)      (None, 12, 12, 192)          0         ['block6g_project_bn[0][0]']
#
#  block6g_add (Add)           (None, 12, 12, 192)          0         ['block6g_drop[0][0]',
#                                                                      'block6f_add[0][0]']
#
#  block6h_expand_conv (Conv2  (None, 12, 12, 1152)         221184    ['block6g_add[0][0]']
#  D)
#
#  block6h_expand_bn (BatchNo  (None, 12, 12, 1152)         4608      ['block6h_expand_conv[0][0]']
#  rmalization)
#
#  block6h_expand_activation   (None, 12, 12, 1152)         0         ['block6h_expand_bn[0][0]']
#  (Activation)
#
#  block6h_dwconv2 (Depthwise  (None, 12, 12, 1152)         10368     ['block6h_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6h_bn (BatchNormaliza  (None, 12, 12, 1152)         4608      ['block6h_dwconv2[0][0]']
#  tion)
#
#  block6h_activation (Activa  (None, 12, 12, 1152)         0         ['block6h_bn[0][0]']
#  tion)
#
#  block6h_se_squeeze (Global  (None, 1152)                 0         ['block6h_activation[0][0]']
#  AveragePooling2D)
#
#  block6h_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6h_se_squeeze[0][0]']
#  e)
#
#  block6h_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6h_se_reshape[0][0]']
#
#  block6h_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6h_se_reduce[0][0]']
#
#  block6h_se_excite (Multipl  (None, 12, 12, 1152)         0         ['block6h_activation[0][0]',
#  y)                                                                  'block6h_se_expand[0][0]']
#
#  block6h_project_conv (Conv  (None, 12, 12, 192)          221184    ['block6h_se_excite[0][0]']
#  2D)
#
#  block6h_project_bn (BatchN  (None, 12, 12, 192)          768       ['block6h_project_conv[0][0]']
#  ormalization)
#
#  block6h_drop (Dropout)      (None, 12, 12, 192)          0         ['block6h_project_bn[0][0]']
#
#  block6h_add (Add)           (None, 12, 12, 192)          0         ['block6h_drop[0][0]',
#                                                                      'block6g_add[0][0]']
#
#  top_conv (Conv2D)           (None, 12, 12, 1280)         245760    ['block6h_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 12, 12, 1280)         5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 12, 12, 1280)         0         ['top_bn[0][0]']
#  )
#
#  avg_pool (GlobalAveragePoo  (None, 1280)                 0         ['top_activation[0][0]']
#  ling2D)
#
#  dense_14 (Dense)            (None, 64)                   81984     ['avg_pool[0][0]']
#
#  dense_15 (Dense)            (None, 32)                   2080      ['dense_14[0][0]']
#
#  dense_17 (Dense)            (None, 64)                   81984     ['avg_pool[0][0]']
#
#  dense_19 (Dense)            (None, 64)                   81984     ['avg_pool[0][0]']
#
#  dense_16 (Dense)            (None, 1)                    33        ['dense_15[0][0]']
#
#  dense_18 (Dense)            (None, 32)                   2080      ['dense_17[0][0]']
#
#  dense_20 (Dense)            (None, 32)                   2080      ['dense_19[0][0]']
#
#  Score (Lambda)              (None, 1)                    0         ['dense_16[0][0]']
#
#  gender (Dense)              (None, 2)                    66        ['dense_18[0][0]']
#
#  smile (Dense)               (None, 2)                    66        ['dense_20[0][0]']
#
# ==================================================================================================
# Total params: 6171669 (23.54 MB)
# Trainable params: 6111061 (23.31 MB)
# Non-trainable params: 60608 (236.75 KB)
# __________________________________________________________________________________________________

# %%
tlr = tfa.optimizers.TriangularCyclicalLearningRate(
        initial_learning_rate = 1e-5,
        maximal_learning_rate = 1e-3,
        step_size = len(train_dataset),
        scale_mode = "cycle")

optimizer = tf.keras.optimizers.AdamW(learning_rate=tlr)
loss = {'Score': tf.keras.losses.Huber(delta=0.5), #'mse',
        'gender': tf.keras.losses.SparseCategoricalCrossentropy(),
       'smile': tf.keras.losses.SparseCategoricalCrossentropy()} 

metrics = {'Score': tf.keras.metrics.RootMeanSquaredError(),
        'gender': 'accuracy',
          'smile': 'accuracy'}

model.compile(
    optimizer=optimizer,
    loss=loss,
    metrics=metrics
)

# %%
# Define the checkpoint callback كيش ايبوخ جيتره 
checkpoint = ModelCheckpoint(
    filepath="model_checkpoint.h5",
    monitor="val_Score_root_mean_squared_error", # val_loss
    save_best_only=True,
    verbose=1
)

# %%
history = model.fit(train_dataset,validation_data=valid_dataset,epochs=100, callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 25/25 [==============================] - ETA: 0s - loss: 1.2579 - Score_loss: 0.1555 - gender_loss: 0.4308 - smile_loss: 0.6716 - Score_root_mean_squared_error: 0.6392 - gender_accuracy: 0.8062 - smile_accuracy: 0.5562
# Epoch 1: val_Score_root_mean_squared_error improved from inf to 0.61256, saving model to model_checkpoint.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 25/25 [==============================] - 52s 455ms/step - loss: 1.2579 - Score_loss: 0.1555 - gender_loss: 0.4308 - smile_loss: 0.6716 - Score_root_mean_squared_error: 0.6392 - gender_accuracy: 0.8062 - smile_accuracy: 0.5562 - val_loss: 0.8938 - val_Score_loss: 0.1487 - val_gender_loss: 0.1113 - val_smile_loss: 0.6339 - val_Score_root_mean_squared_error: 0.6126 - val_gender_accuracy: 0.9400 - val_smile_accuracy: 0.6500
# Epoch 2/100
# 25/25 [==============================] - ETA: 0s - loss: 0.6392 - Score_loss: 0.1339 - gender_loss: 0.1026 - smile_loss: 0.4027 - Score_root_mean_squared_error: 0.5793 - gender_accuracy: 0.9650 - smile_accuracy: 0.8025
# Epoch 2: val_Score_root_mean_squared_error improved from 0.61256 to 0.57972, saving model to model_checkpoint.h5
# 25/25 [==============================] - 10s 387ms/step - loss: 0.6392 - Score_loss: 0.1339 - gender_loss: 0.1026 - smile_loss: 0.4027 - Score_root_mean_squared_error: 0.5793 - gender_accuracy: 0.9650 - smile_accuracy: 0.8025 - val_loss: 0.4907 - val_Score_loss: 0.1314 - val_gender_loss: 0.0088 - val_smile_loss: 0.3505 - val_Score_root_mean_squared_error: 0.5797 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8600
# Epoch 3/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3992 - Score_loss: 0.1152 - gender_loss: 0.0442 - smile_loss: 0.2399 - Score_root_mean_squared_error: 0.5267 - gender_accuracy: 0.9812 - smile_accuracy: 0.9025
# Epoch 3: val_Score_root_mean_squared_error did not improve from 0.57972
# 25/25 [==============================] - 10s 352ms/step - loss: 0.3992 - Score_loss: 0.1152 - gender_loss: 0.0442 - smile_loss: 0.2399 - Score_root_mean_squared_error: 0.5267 - gender_accuracy: 0.9812 - smile_accuracy: 0.9025 - val_loss: 0.6444 - val_Score_loss: 0.1439 - val_gender_loss: 0.0367 - val_smile_loss: 0.4638 - val_Score_root_mean_squared_error: 0.6141 - val_gender_accuracy: 0.9800 - val_smile_accuracy: 0.8700
# Epoch 4/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3006 - Score_loss: 0.1020 - gender_loss: 0.0187 - smile_loss: 0.1799 - Score_root_mean_squared_error: 0.4958 - gender_accuracy: 0.9937 - smile_accuracy: 0.9287
# Epoch 4: val_Score_root_mean_squared_error did not improve from 0.57972
# 25/25 [==============================] - 10s 352ms/step - loss: 0.3006 - Score_loss: 0.1020 - gender_loss: 0.0187 - smile_loss: 0.1799 - Score_root_mean_squared_error: 0.4958 - gender_accuracy: 0.9937 - smile_accuracy: 0.9287 - val_loss: 0.4986 - val_Score_loss: 0.1425 - val_gender_loss: 0.0072 - val_smile_loss: 0.3490 - val_Score_root_mean_squared_error: 0.6109 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8900
# Epoch 5/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2444 - Score_loss: 0.0875 - gender_loss: 0.0225 - smile_loss: 0.1344 - Score_root_mean_squared_error: 0.4530 - gender_accuracy: 0.9925 - smile_accuracy: 0.9525
# Epoch 5: val_Score_root_mean_squared_error improved from 0.57972 to 0.57553, saving model to model_checkpoint.h5
# 25/25 [==============================] - 11s 388ms/step - loss: 0.2444 - Score_loss: 0.0875 - gender_loss: 0.0225 - smile_loss: 0.1344 - Score_root_mean_squared_error: 0.4530 - gender_accuracy: 0.9925 - smile_accuracy: 0.9525 - val_loss: 0.5375 - val_Score_loss: 0.1300 - val_gender_loss: 0.0334 - val_smile_loss: 0.3741 - val_Score_root_mean_squared_error: 0.5755 - val_gender_accuracy: 0.9900 - val_smile_accuracy: 0.8600
# Epoch 6/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2108 - Score_loss: 0.0832 - gender_loss: 0.0286 - smile_loss: 0.0990 - Score_root_mean_squared_error: 0.4337 - gender_accuracy: 0.9900 - smile_accuracy: 0.9725
# Epoch 6: val_Score_root_mean_squared_error did not improve from 0.57553
# 25/25 [==============================] - 10s 353ms/step - loss: 0.2108 - Score_loss: 0.0832 - gender_loss: 0.0286 - smile_loss: 0.0990 - Score_root_mean_squared_error: 0.4337 - gender_accuracy: 0.9900 - smile_accuracy: 0.9725 - val_loss: 0.6775 - val_Score_loss: 0.1443 - val_gender_loss: 0.0054 - val_smile_loss: 0.5278 - val_Score_root_mean_squared_error: 0.6138 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8400
# Epoch 7/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1682 - Score_loss: 0.0688 - gender_loss: 0.0362 - smile_loss: 0.0632 - Score_root_mean_squared_error: 0.3967 - gender_accuracy: 0.9900 - smile_accuracy: 0.9825
# Epoch 7: val_Score_root_mean_squared_error did not improve from 0.57553
# 25/25 [==============================] - 9s 344ms/step - loss: 0.1682 - Score_loss: 0.0688 - gender_loss: 0.0362 - smile_loss: 0.0632 - Score_root_mean_squared_error: 0.3967 - gender_accuracy: 0.9900 - smile_accuracy: 0.9825 - val_loss: 0.8417 - val_Score_loss: 0.1453 - val_gender_loss: 0.0155 - val_smile_loss: 0.6809 - val_Score_root_mean_squared_error: 0.6048 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8200
# Epoch 8/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1745 - Score_loss: 0.0652 - gender_loss: 0.0199 - smile_loss: 0.0894 - Score_root_mean_squared_error: 0.3797 - gender_accuracy: 0.9900 - smile_accuracy: 0.9638
# Epoch 8: val_Score_root_mean_squared_error did not improve from 0.57553
# 25/25 [==============================] - 9s 344ms/step - loss: 0.1745 - Score_loss: 0.0652 - gender_loss: 0.0199 - smile_loss: 0.0894 - Score_root_mean_squared_error: 0.3797 - gender_accuracy: 0.9900 - smile_accuracy: 0.9638 - val_loss: 0.5042 - val_Score_loss: 0.1475 - val_gender_loss: 0.0167 - val_smile_loss: 0.3400 - val_Score_root_mean_squared_error: 0.6254 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8900
# Epoch 9/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1052 - Score_loss: 0.0578 - gender_loss: 0.0052 - smile_loss: 0.0422 - Score_root_mean_squared_error: 0.3574 - gender_accuracy: 1.0000 - smile_accuracy: 0.9812
# Epoch 9: val_Score_root_mean_squared_error did not improve from 0.57553
# 25/25 [==============================] - 10s 343ms/step - loss: 0.1052 - Score_loss: 0.0578 - gender_loss: 0.0052 - smile_loss: 0.0422 - Score_root_mean_squared_error: 0.3574 - gender_accuracy: 1.0000 - smile_accuracy: 0.9812 - val_loss: 0.7631 - val_Score_loss: 0.1457 - val_gender_loss: 0.0303 - val_smile_loss: 0.5871 - val_Score_root_mean_squared_error: 0.6318 - val_gender_accuracy: 0.9800 - val_smile_accuracy: 0.8500
# Epoch 10/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1289 - Score_loss: 0.0514 - gender_loss: 0.0053 - smile_loss: 0.0721 - Score_root_mean_squared_error: 0.3304 - gender_accuracy: 0.9987 - smile_accuracy: 0.9787
# Epoch 10: val_Score_root_mean_squared_error did not improve from 0.57553
# 25/25 [==============================] - 9s 344ms/step - loss: 0.1289 - Score_loss: 0.0514 - gender_loss: 0.0053 - smile_loss: 0.0721 - Score_root_mean_squared_error: 0.3304 - gender_accuracy: 0.9987 - smile_accuracy: 0.9787 - val_loss: 0.4809 - val_Score_loss: 0.1430 - val_gender_loss: 0.0313 - val_smile_loss: 0.3066 - val_Score_root_mean_squared_error: 0.6167 - val_gender_accuracy: 0.9900 - val_smile_accuracy: 0.9000
# Epoch 11/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0937 - Score_loss: 0.0442 - gender_loss: 0.0059 - smile_loss: 0.0436 - Score_root_mean_squared_error: 0.3074 - gender_accuracy: 0.9987 - smile_accuracy: 0.9837
# Epoch 11: val_Score_root_mean_squared_error did not improve from 0.57553
# 25/25 [==============================] - 10s 351ms/step - loss: 0.0937 - Score_loss: 0.0442 - gender_loss: 0.0059 - smile_loss: 0.0436 - Score_root_mean_squared_error: 0.3074 - gender_accuracy: 0.9987 - smile_accuracy: 0.9837 - val_loss: 0.6926 - val_Score_loss: 0.1371 - val_gender_loss: 0.0039 - val_smile_loss: 0.5516 - val_Score_root_mean_squared_error: 0.6010 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8600
# Epoch 12/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0967 - Score_loss: 0.0388 - gender_loss: 0.0039 - smile_loss: 0.0540 - Score_root_mean_squared_error: 0.2852 - gender_accuracy: 1.0000 - smile_accuracy: 0.9762
# Epoch 12: val_Score_root_mean_squared_error did not improve from 0.57553
# 25/25 [==============================] - 10s 353ms/step - loss: 0.0967 - Score_loss: 0.0388 - gender_loss: 0.0039 - smile_loss: 0.0540 - Score_root_mean_squared_error: 0.2852 - gender_accuracy: 1.0000 - smile_accuracy: 0.9762 - val_loss: 0.4442 - val_Score_loss: 0.1393 - val_gender_loss: 0.0050 - val_smile_loss: 0.3000 - val_Score_root_mean_squared_error: 0.5960 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9300
# Epoch 13/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0743 - Score_loss: 0.0355 - gender_loss: 0.0102 - smile_loss: 0.0285 - Score_root_mean_squared_error: 0.2707 - gender_accuracy: 0.9950 - smile_accuracy: 0.9912
# Epoch 13: val_Score_root_mean_squared_error did not improve from 0.57553
# 25/25 [==============================] - 10s 351ms/step - loss: 0.0743 - Score_loss: 0.0355 - gender_loss: 0.0102 - smile_loss: 0.0285 - Score_root_mean_squared_error: 0.2707 - gender_accuracy: 0.9950 - smile_accuracy: 0.9912 - val_loss: 0.7180 - val_Score_loss: 0.1547 - val_gender_loss: 0.1046 - val_smile_loss: 0.4587 - val_Score_root_mean_squared_error: 0.6350 - val_gender_accuracy: 0.9500 - val_smile_accuracy: 0.8700
# Epoch 14/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0962 - Score_loss: 0.0356 - gender_loss: 0.0228 - smile_loss: 0.0378 - Score_root_mean_squared_error: 0.2693 - gender_accuracy: 0.9900 - smile_accuracy: 0.9875
# Epoch 14: val_Score_root_mean_squared_error did not improve from 0.57553
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0962 - Score_loss: 0.0356 - gender_loss: 0.0228 - smile_loss: 0.0378 - Score_root_mean_squared_error: 0.2693 - gender_accuracy: 0.9900 - smile_accuracy: 0.9875 - val_loss: 0.6062 - val_Score_loss: 0.1317 - val_gender_loss: 0.0042 - val_smile_loss: 0.4703 - val_Score_root_mean_squared_error: 0.5881 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8700
# Epoch 15/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0699 - Score_loss: 0.0308 - gender_loss: 0.0060 - smile_loss: 0.0331 - Score_root_mean_squared_error: 0.2499 - gender_accuracy: 0.9987 - smile_accuracy: 0.9900
# Epoch 15: val_Score_root_mean_squared_error did not improve from 0.57553
# 25/25 [==============================] - 10s 353ms/step - loss: 0.0699 - Score_loss: 0.0308 - gender_loss: 0.0060 - smile_loss: 0.0331 - Score_root_mean_squared_error: 0.2499 - gender_accuracy: 0.9987 - smile_accuracy: 0.9900 - val_loss: 0.4909 - val_Score_loss: 0.1324 - val_gender_loss: 0.0022 - val_smile_loss: 0.3562 - val_Score_root_mean_squared_error: 0.5770 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8900
# Epoch 16/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0877 - Score_loss: 0.0338 - gender_loss: 0.0163 - smile_loss: 0.0376 - Score_root_mean_squared_error: 0.2663 - gender_accuracy: 0.9925 - smile_accuracy: 0.9900
# Epoch 16: val_Score_root_mean_squared_error improved from 0.57553 to 0.56851, saving model to model_checkpoint.h5
# 25/25 [==============================] - 10s 381ms/step - loss: 0.0877 - Score_loss: 0.0338 - gender_loss: 0.0163 - smile_loss: 0.0376 - Score_root_mean_squared_error: 0.2663 - gender_accuracy: 0.9925 - smile_accuracy: 0.9900 - val_loss: 0.5849 - val_Score_loss: 0.1287 - val_gender_loss: 0.0039 - val_smile_loss: 0.4523 - val_Score_root_mean_squared_error: 0.5685 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9000
# Epoch 17/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0496 - Score_loss: 0.0252 - gender_loss: 0.0027 - smile_loss: 0.0218 - Score_root_mean_squared_error: 0.2265 - gender_accuracy: 0.9987 - smile_accuracy: 0.9900
# Epoch 17: val_Score_root_mean_squared_error did not improve from 0.56851
# 25/25 [==============================] - 9s 343ms/step - loss: 0.0496 - Score_loss: 0.0252 - gender_loss: 0.0027 - smile_loss: 0.0218 - Score_root_mean_squared_error: 0.2265 - gender_accuracy: 0.9987 - smile_accuracy: 0.9900 - val_loss: 0.4814 - val_Score_loss: 0.1509 - val_gender_loss: 0.0077 - val_smile_loss: 0.3228 - val_Score_root_mean_squared_error: 0.6302 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8800
# Epoch 18/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0554 - Score_loss: 0.0292 - gender_loss: 0.0010 - smile_loss: 0.0252 - Score_root_mean_squared_error: 0.2435 - gender_accuracy: 1.0000 - smile_accuracy: 0.9875
# Epoch 18: val_Score_root_mean_squared_error did not improve from 0.56851
# 25/25 [==============================] - 10s 354ms/step - loss: 0.0554 - Score_loss: 0.0292 - gender_loss: 0.0010 - smile_loss: 0.0252 - Score_root_mean_squared_error: 0.2435 - gender_accuracy: 1.0000 - smile_accuracy: 0.9875 - val_loss: 0.4693 - val_Score_loss: 0.1276 - val_gender_loss: 0.0027 - val_smile_loss: 0.3391 - val_Score_root_mean_squared_error: 0.5813 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9000
# Epoch 19/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0450 - Score_loss: 0.0255 - gender_loss: 6.4223e-04 - smile_loss: 0.0188 - Score_root_mean_squared_error: 0.2301 - gender_accuracy: 1.0000 - smile_accuracy: 0.9937
# Epoch 19: val_Score_root_mean_squared_error did not improve from 0.56851
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0450 - Score_loss: 0.0255 - gender_loss: 6.4223e-04 - smile_loss: 0.0188 - Score_root_mean_squared_error: 0.2301 - gender_accuracy: 1.0000 - smile_accuracy: 0.9937 - val_loss: 0.6924 - val_Score_loss: 0.1394 - val_gender_loss: 0.0038 - val_smile_loss: 0.5492 - val_Score_root_mean_squared_error: 0.6106 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8400
# Epoch 20/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0458 - Score_loss: 0.0233 - gender_loss: 0.0013 - smile_loss: 0.0212 - Score_root_mean_squared_error: 0.2167 - gender_accuracy: 1.0000 - smile_accuracy: 0.9925
# Epoch 20: val_Score_root_mean_squared_error did not improve from 0.56851
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0458 - Score_loss: 0.0233 - gender_loss: 0.0013 - smile_loss: 0.0212 - Score_root_mean_squared_error: 0.2167 - gender_accuracy: 1.0000 - smile_accuracy: 0.9925 - val_loss: 0.5043 - val_Score_loss: 0.1345 - val_gender_loss: 0.0012 - val_smile_loss: 0.3686 - val_Score_root_mean_squared_error: 0.5933 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8800
# Epoch 21/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0353 - Score_loss: 0.0188 - gender_loss: 0.0044 - smile_loss: 0.0121 - Score_root_mean_squared_error: 0.1941 - gender_accuracy: 0.9987 - smile_accuracy: 0.9962
# Epoch 21: val_Score_root_mean_squared_error did not improve from 0.56851
# 25/25 [==============================] - 9s 343ms/step - loss: 0.0353 - Score_loss: 0.0188 - gender_loss: 0.0044 - smile_loss: 0.0121 - Score_root_mean_squared_error: 0.1941 - gender_accuracy: 0.9987 - smile_accuracy: 0.9962 - val_loss: 0.5139 - val_Score_loss: 0.1365 - val_gender_loss: 0.0079 - val_smile_loss: 0.3695 - val_Score_root_mean_squared_error: 0.6027 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9200
# Epoch 22/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0901 - Score_loss: 0.0284 - gender_loss: 0.0272 - smile_loss: 0.0345 - Score_root_mean_squared_error: 0.2411 - gender_accuracy: 0.9900 - smile_accuracy: 0.9850
# Epoch 22: val_Score_root_mean_squared_error improved from 0.56851 to 0.56839, saving model to model_checkpoint.h5
# 25/25 [==============================] - 10s 390ms/step - loss: 0.0901 - Score_loss: 0.0284 - gender_loss: 0.0272 - smile_loss: 0.0345 - Score_root_mean_squared_error: 0.2411 - gender_accuracy: 0.9900 - smile_accuracy: 0.9850 - val_loss: 0.7139 - val_Score_loss: 0.1285 - val_gender_loss: 0.0915 - val_smile_loss: 0.4939 - val_Score_root_mean_squared_error: 0.5684 - val_gender_accuracy: 0.9700 - val_smile_accuracy: 0.8800
# Epoch 23/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0702 - Score_loss: 0.0256 - gender_loss: 0.0215 - smile_loss: 0.0231 - Score_root_mean_squared_error: 0.2284 - gender_accuracy: 0.9925 - smile_accuracy: 0.9925
# Epoch 23: val_Score_root_mean_squared_error did not improve from 0.56839
# 25/25 [==============================] - 9s 343ms/step - loss: 0.0702 - Score_loss: 0.0256 - gender_loss: 0.0215 - smile_loss: 0.0231 - Score_root_mean_squared_error: 0.2284 - gender_accuracy: 0.9925 - smile_accuracy: 0.9925 - val_loss: 0.7893 - val_Score_loss: 0.1381 - val_gender_loss: 0.1255 - val_smile_loss: 0.5257 - val_Score_root_mean_squared_error: 0.5916 - val_gender_accuracy: 0.9800 - val_smile_accuracy: 0.8600
# Epoch 24/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1742 - Score_loss: 0.0324 - gender_loss: 0.0923 - smile_loss: 0.0495 - Score_root_mean_squared_error: 0.2572 - gender_accuracy: 0.9775 - smile_accuracy: 0.9837
# Epoch 24: val_Score_root_mean_squared_error did not improve from 0.56839
# 25/25 [==============================] - 10s 351ms/step - loss: 0.1742 - Score_loss: 0.0324 - gender_loss: 0.0923 - smile_loss: 0.0495 - Score_root_mean_squared_error: 0.2572 - gender_accuracy: 0.9775 - smile_accuracy: 0.9837 - val_loss: 0.4612 - val_Score_loss: 0.1316 - val_gender_loss: 0.0153 - val_smile_loss: 0.3143 - val_Score_root_mean_squared_error: 0.5915 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8800
# Epoch 25/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0917 - Score_loss: 0.0359 - gender_loss: 0.0156 - smile_loss: 0.0402 - Score_root_mean_squared_error: 0.2718 - gender_accuracy: 0.9962 - smile_accuracy: 0.9862
# Epoch 25: val_Score_root_mean_squared_error did not improve from 0.56839
# 25/25 [==============================] - 10s 353ms/step - loss: 0.0917 - Score_loss: 0.0359 - gender_loss: 0.0156 - smile_loss: 0.0402 - Score_root_mean_squared_error: 0.2718 - gender_accuracy: 0.9962 - smile_accuracy: 0.9862 - val_loss: 0.4690 - val_Score_loss: 0.1345 - val_gender_loss: 0.0098 - val_smile_loss: 0.3247 - val_Score_root_mean_squared_error: 0.5905 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9200
# Epoch 26/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1013 - Score_loss: 0.0393 - gender_loss: 0.0225 - smile_loss: 0.0395 - Score_root_mean_squared_error: 0.2859 - gender_accuracy: 0.9925 - smile_accuracy: 0.9850
# Epoch 26: val_Score_root_mean_squared_error did not improve from 0.56839
# 25/25 [==============================] - 10s 352ms/step - loss: 0.1013 - Score_loss: 0.0393 - gender_loss: 0.0225 - smile_loss: 0.0395 - Score_root_mean_squared_error: 0.2859 - gender_accuracy: 0.9925 - smile_accuracy: 0.9850 - val_loss: 0.6110 - val_Score_loss: 0.1368 - val_gender_loss: 0.0062 - val_smile_loss: 0.4680 - val_Score_root_mean_squared_error: 0.5931 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9200
# Epoch 27/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0757 - Score_loss: 0.0258 - gender_loss: 0.0133 - smile_loss: 0.0366 - Score_root_mean_squared_error: 0.2279 - gender_accuracy: 0.9950 - smile_accuracy: 0.9875
# Epoch 27: val_Score_root_mean_squared_error improved from 0.56839 to 0.56450, saving model to model_checkpoint.h5
# 25/25 [==============================] - 10s 379ms/step - loss: 0.0757 - Score_loss: 0.0258 - gender_loss: 0.0133 - smile_loss: 0.0366 - Score_root_mean_squared_error: 0.2279 - gender_accuracy: 0.9950 - smile_accuracy: 0.9875 - val_loss: 0.4781 - val_Score_loss: 0.1241 - val_gender_loss: 0.0021 - val_smile_loss: 0.3519 - val_Score_root_mean_squared_error: 0.5645 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9000
# Epoch 28/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0619 - Score_loss: 0.0281 - gender_loss: 0.0117 - smile_loss: 0.0221 - Score_root_mean_squared_error: 0.2399 - gender_accuracy: 0.9987 - smile_accuracy: 0.9912
# Epoch 28: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 354ms/step - loss: 0.0619 - Score_loss: 0.0281 - gender_loss: 0.0117 - smile_loss: 0.0221 - Score_root_mean_squared_error: 0.2399 - gender_accuracy: 0.9987 - smile_accuracy: 0.9912 - val_loss: 0.6161 - val_Score_loss: 0.1275 - val_gender_loss: 0.0229 - val_smile_loss: 0.4657 - val_Score_root_mean_squared_error: 0.5712 - val_gender_accuracy: 0.9900 - val_smile_accuracy: 0.8900
# Epoch 29/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0412 - Score_loss: 0.0205 - gender_loss: 0.0113 - smile_loss: 0.0095 - Score_root_mean_squared_error: 0.2026 - gender_accuracy: 0.9950 - smile_accuracy: 0.9987
# Epoch 29: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 9s 343ms/step - loss: 0.0412 - Score_loss: 0.0205 - gender_loss: 0.0113 - smile_loss: 0.0095 - Score_root_mean_squared_error: 0.2026 - gender_accuracy: 0.9950 - smile_accuracy: 0.9987 - val_loss: 0.9068 - val_Score_loss: 0.1482 - val_gender_loss: 0.0089 - val_smile_loss: 0.7497 - val_Score_root_mean_squared_error: 0.6258 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8700
# Epoch 30/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0510 - Score_loss: 0.0244 - gender_loss: 0.0053 - smile_loss: 0.0213 - Score_root_mean_squared_error: 0.2223 - gender_accuracy: 0.9975 - smile_accuracy: 0.9912
# Epoch 30: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 351ms/step - loss: 0.0510 - Score_loss: 0.0244 - gender_loss: 0.0053 - smile_loss: 0.0213 - Score_root_mean_squared_error: 0.2223 - gender_accuracy: 0.9975 - smile_accuracy: 0.9912 - val_loss: 0.5927 - val_Score_loss: 0.1415 - val_gender_loss: 0.0101 - val_smile_loss: 0.4411 - val_Score_root_mean_squared_error: 0.6086 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8700
# Epoch 31/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0571 - Score_loss: 0.0194 - gender_loss: 0.0026 - smile_loss: 0.0351 - Score_root_mean_squared_error: 0.1978 - gender_accuracy: 1.0000 - smile_accuracy: 0.9862
# Epoch 31: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 9s 344ms/step - loss: 0.0571 - Score_loss: 0.0194 - gender_loss: 0.0026 - smile_loss: 0.0351 - Score_root_mean_squared_error: 0.1978 - gender_accuracy: 1.0000 - smile_accuracy: 0.9862 - val_loss: 0.5787 - val_Score_loss: 0.1272 - val_gender_loss: 0.0236 - val_smile_loss: 0.4279 - val_Score_root_mean_squared_error: 0.5744 - val_gender_accuracy: 0.9900 - val_smile_accuracy: 0.8800
# Epoch 32/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0609 - Score_loss: 0.0233 - gender_loss: 0.0097 - smile_loss: 0.0279 - Score_root_mean_squared_error: 0.2161 - gender_accuracy: 0.9962 - smile_accuracy: 0.9900
# Epoch 32: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0609 - Score_loss: 0.0233 - gender_loss: 0.0097 - smile_loss: 0.0279 - Score_root_mean_squared_error: 0.2161 - gender_accuracy: 0.9962 - smile_accuracy: 0.9900 - val_loss: 0.7168 - val_Score_loss: 0.1321 - val_gender_loss: 0.0064 - val_smile_loss: 0.5783 - val_Score_root_mean_squared_error: 0.5775 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8600
# Epoch 33/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0280 - Score_loss: 0.0170 - gender_loss: 0.0025 - smile_loss: 0.0085 - Score_root_mean_squared_error: 0.1844 - gender_accuracy: 0.9987 - smile_accuracy: 0.9987
# Epoch 33: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0280 - Score_loss: 0.0170 - gender_loss: 0.0025 - smile_loss: 0.0085 - Score_root_mean_squared_error: 0.1844 - gender_accuracy: 0.9987 - smile_accuracy: 0.9987 - val_loss: 0.4472 - val_Score_loss: 0.1432 - val_gender_loss: 0.0050 - val_smile_loss: 0.2990 - val_Score_root_mean_squared_error: 0.6078 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9000
# Epoch 34/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0296 - Score_loss: 0.0182 - gender_loss: 0.0027 - smile_loss: 0.0087 - Score_root_mean_squared_error: 0.1912 - gender_accuracy: 0.9987 - smile_accuracy: 0.9975
# Epoch 34: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0296 - Score_loss: 0.0182 - gender_loss: 0.0027 - smile_loss: 0.0087 - Score_root_mean_squared_error: 0.1912 - gender_accuracy: 0.9987 - smile_accuracy: 0.9975 - val_loss: 0.4457 - val_Score_loss: 0.1418 - val_gender_loss: 0.0018 - val_smile_loss: 0.3021 - val_Score_root_mean_squared_error: 0.5988 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9000
# Epoch 35/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0225 - Score_loss: 0.0180 - gender_loss: 6.6715e-04 - smile_loss: 0.0038 - Score_root_mean_squared_error: 0.1900 - gender_accuracy: 1.0000 - smile_accuracy: 0.9987
# Epoch 35: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 9s 344ms/step - loss: 0.0225 - Score_loss: 0.0180 - gender_loss: 6.6715e-04 - smile_loss: 0.0038 - Score_root_mean_squared_error: 0.1900 - gender_accuracy: 1.0000 - smile_accuracy: 0.9987 - val_loss: 0.5267 - val_Score_loss: 0.1436 - val_gender_loss: 8.1369e-04 - val_smile_loss: 0.3823 - val_Score_root_mean_squared_error: 0.6060 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9200
# Epoch 36/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0411 - Score_loss: 0.0172 - gender_loss: 0.0029 - smile_loss: 0.0211 - Score_root_mean_squared_error: 0.1859 - gender_accuracy: 1.0000 - smile_accuracy: 0.9900
# Epoch 36: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 351ms/step - loss: 0.0411 - Score_loss: 0.0172 - gender_loss: 0.0029 - smile_loss: 0.0211 - Score_root_mean_squared_error: 0.1859 - gender_accuracy: 1.0000 - smile_accuracy: 0.9900 - val_loss: 0.5127 - val_Score_loss: 0.1366 - val_gender_loss: 0.0417 - val_smile_loss: 0.3344 - val_Score_root_mean_squared_error: 0.5896 - val_gender_accuracy: 0.9900 - val_smile_accuracy: 0.9500
# Epoch 37/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0307 - Score_loss: 0.0168 - gender_loss: 0.0105 - smile_loss: 0.0034 - Score_root_mean_squared_error: 0.1833 - gender_accuracy: 0.9975 - smile_accuracy: 0.9987
# Epoch 37: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 351ms/step - loss: 0.0307 - Score_loss: 0.0168 - gender_loss: 0.0105 - smile_loss: 0.0034 - Score_root_mean_squared_error: 0.1833 - gender_accuracy: 0.9975 - smile_accuracy: 0.9987 - val_loss: 0.5993 - val_Score_loss: 0.1471 - val_gender_loss: 0.0379 - val_smile_loss: 0.4143 - val_Score_root_mean_squared_error: 0.6123 - val_gender_accuracy: 0.9800 - val_smile_accuracy: 0.8900
# Epoch 38/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0410 - Score_loss: 0.0206 - gender_loss: 0.0036 - smile_loss: 0.0169 - Score_root_mean_squared_error: 0.2037 - gender_accuracy: 1.0000 - smile_accuracy: 0.9962
# Epoch 38: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 353ms/step - loss: 0.0410 - Score_loss: 0.0206 - gender_loss: 0.0036 - smile_loss: 0.0169 - Score_root_mean_squared_error: 0.2037 - gender_accuracy: 1.0000 - smile_accuracy: 0.9962 - val_loss: 0.7660 - val_Score_loss: 0.1409 - val_gender_loss: 0.0755 - val_smile_loss: 0.5496 - val_Score_root_mean_squared_error: 0.6009 - val_gender_accuracy: 0.9800 - val_smile_accuracy: 0.8800
# Epoch 39/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0272 - Score_loss: 0.0153 - gender_loss: 0.0043 - smile_loss: 0.0076 - Score_root_mean_squared_error: 0.1752 - gender_accuracy: 0.9975 - smile_accuracy: 0.9962
# Epoch 39: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 353ms/step - loss: 0.0272 - Score_loss: 0.0153 - gender_loss: 0.0043 - smile_loss: 0.0076 - Score_root_mean_squared_error: 0.1752 - gender_accuracy: 0.9975 - smile_accuracy: 0.9962 - val_loss: 0.5561 - val_Score_loss: 0.1399 - val_gender_loss: 5.6624e-04 - val_smile_loss: 0.4157 - val_Score_root_mean_squared_error: 0.5976 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8900
# Epoch 40/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0298 - Score_loss: 0.0165 - gender_loss: 6.3939e-04 - smile_loss: 0.0126 - Score_root_mean_squared_error: 0.1822 - gender_accuracy: 1.0000 - smile_accuracy: 0.9975
# Epoch 40: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0298 - Score_loss: 0.0165 - gender_loss: 6.3939e-04 - smile_loss: 0.0126 - Score_root_mean_squared_error: 0.1822 - gender_accuracy: 1.0000 - smile_accuracy: 0.9975 - val_loss: 0.4961 - val_Score_loss: 0.1418 - val_gender_loss: 6.3427e-04 - val_smile_loss: 0.3537 - val_Score_root_mean_squared_error: 0.6099 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9100
# Epoch 41/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0261 - Score_loss: 0.0112 - gender_loss: 0.0022 - smile_loss: 0.0126 - Score_root_mean_squared_error: 0.1500 - gender_accuracy: 0.9987 - smile_accuracy: 0.9975
# Epoch 41: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 354ms/step - loss: 0.0261 - Score_loss: 0.0112 - gender_loss: 0.0022 - smile_loss: 0.0126 - Score_root_mean_squared_error: 0.1500 - gender_accuracy: 0.9987 - smile_accuracy: 0.9975 - val_loss: 0.6598 - val_Score_loss: 0.1461 - val_gender_loss: 0.0710 - val_smile_loss: 0.4427 - val_Score_root_mean_squared_error: 0.6242 - val_gender_accuracy: 0.9800 - val_smile_accuracy: 0.8900
# Epoch 42/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0351 - Score_loss: 0.0160 - gender_loss: 0.0149 - smile_loss: 0.0043 - Score_root_mean_squared_error: 0.1793 - gender_accuracy: 0.9962 - smile_accuracy: 0.9987
# Epoch 42: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0351 - Score_loss: 0.0160 - gender_loss: 0.0149 - smile_loss: 0.0043 - Score_root_mean_squared_error: 0.1793 - gender_accuracy: 0.9962 - smile_accuracy: 0.9987 - val_loss: 0.5112 - val_Score_loss: 0.1400 - val_gender_loss: 0.0233 - val_smile_loss: 0.3479 - val_Score_root_mean_squared_error: 0.6046 - val_gender_accuracy: 0.9900 - val_smile_accuracy: 0.8900
# Epoch 43/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0450 - Score_loss: 0.0144 - gender_loss: 0.0275 - smile_loss: 0.0031 - Score_root_mean_squared_error: 0.1703 - gender_accuracy: 0.9912 - smile_accuracy: 1.0000
# Epoch 43: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 9s 343ms/step - loss: 0.0450 - Score_loss: 0.0144 - gender_loss: 0.0275 - smile_loss: 0.0031 - Score_root_mean_squared_error: 0.1703 - gender_accuracy: 0.9912 - smile_accuracy: 1.0000 - val_loss: 0.6014 - val_Score_loss: 0.1397 - val_gender_loss: 0.0022 - val_smile_loss: 0.4595 - val_Score_root_mean_squared_error: 0.6143 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8800
# Epoch 44/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0482 - Score_loss: 0.0194 - gender_loss: 0.0179 - smile_loss: 0.0109 - Score_root_mean_squared_error: 0.1974 - gender_accuracy: 0.9950 - smile_accuracy: 0.9962
# Epoch 44: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0482 - Score_loss: 0.0194 - gender_loss: 0.0179 - smile_loss: 0.0109 - Score_root_mean_squared_error: 0.1974 - gender_accuracy: 0.9950 - smile_accuracy: 0.9962 - val_loss: 0.6417 - val_Score_loss: 0.1482 - val_gender_loss: 7.7169e-04 - val_smile_loss: 0.4928 - val_Score_root_mean_squared_error: 0.6263 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9000
# Epoch 45/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0607 - Score_loss: 0.0177 - gender_loss: 0.0028 - smile_loss: 0.0402 - Score_root_mean_squared_error: 0.1883 - gender_accuracy: 0.9987 - smile_accuracy: 0.9912
# Epoch 45: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 353ms/step - loss: 0.0607 - Score_loss: 0.0177 - gender_loss: 0.0028 - smile_loss: 0.0402 - Score_root_mean_squared_error: 0.1883 - gender_accuracy: 0.9987 - smile_accuracy: 0.9912 - val_loss: 0.6278 - val_Score_loss: 0.1453 - val_gender_loss: 0.0084 - val_smile_loss: 0.4742 - val_Score_root_mean_squared_error: 0.6235 - val_gender_accuracy: 0.9900 - val_smile_accuracy: 0.8800
# Epoch 46/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1085 - Score_loss: 0.0250 - gender_loss: 0.0118 - smile_loss: 0.0716 - Score_root_mean_squared_error: 0.2243 - gender_accuracy: 0.9950 - smile_accuracy: 0.9762
# Epoch 46: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 351ms/step - loss: 0.1085 - Score_loss: 0.0250 - gender_loss: 0.0118 - smile_loss: 0.0716 - Score_root_mean_squared_error: 0.2243 - gender_accuracy: 0.9950 - smile_accuracy: 0.9762 - val_loss: 0.6097 - val_Score_loss: 0.1359 - val_gender_loss: 0.0085 - val_smile_loss: 0.4653 - val_Score_root_mean_squared_error: 0.5822 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8500
# Epoch 47/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0415 - Score_loss: 0.0214 - gender_loss: 0.0029 - smile_loss: 0.0173 - Score_root_mean_squared_error: 0.2078 - gender_accuracy: 1.0000 - smile_accuracy: 0.9975
# Epoch 47: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0415 - Score_loss: 0.0214 - gender_loss: 0.0029 - smile_loss: 0.0173 - Score_root_mean_squared_error: 0.2078 - gender_accuracy: 1.0000 - smile_accuracy: 0.9975 - val_loss: 0.4932 - val_Score_loss: 0.1451 - val_gender_loss: 0.0047 - val_smile_loss: 0.3434 - val_Score_root_mean_squared_error: 0.6013 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9200
# Epoch 48/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0447 - Score_loss: 0.0194 - gender_loss: 0.0145 - smile_loss: 0.0108 - Score_root_mean_squared_error: 0.1979 - gender_accuracy: 0.9937 - smile_accuracy: 0.9950
# Epoch 48: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 353ms/step - loss: 0.0447 - Score_loss: 0.0194 - gender_loss: 0.0145 - smile_loss: 0.0108 - Score_root_mean_squared_error: 0.1979 - gender_accuracy: 0.9937 - smile_accuracy: 0.9950 - val_loss: 0.5226 - val_Score_loss: 0.1430 - val_gender_loss: 0.0028 - val_smile_loss: 0.3769 - val_Score_root_mean_squared_error: 0.5986 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9200
# Epoch 49/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0339 - Score_loss: 0.0153 - gender_loss: 4.6809e-04 - smile_loss: 0.0181 - Score_root_mean_squared_error: 0.1757 - gender_accuracy: 1.0000 - smile_accuracy: 0.9950
# Epoch 49: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 351ms/step - loss: 0.0339 - Score_loss: 0.0153 - gender_loss: 4.6809e-04 - smile_loss: 0.0181 - Score_root_mean_squared_error: 0.1757 - gender_accuracy: 1.0000 - smile_accuracy: 0.9950 - val_loss: 0.5126 - val_Score_loss: 0.1443 - val_gender_loss: 0.0019 - val_smile_loss: 0.3663 - val_Score_root_mean_squared_error: 0.6029 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9000
# Epoch 50/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0572 - Score_loss: 0.0185 - gender_loss: 0.0030 - smile_loss: 0.0357 - Score_root_mean_squared_error: 0.1933 - gender_accuracy: 0.9987 - smile_accuracy: 0.9875
# Epoch 50: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0572 - Score_loss: 0.0185 - gender_loss: 0.0030 - smile_loss: 0.0357 - Score_root_mean_squared_error: 0.1933 - gender_accuracy: 0.9987 - smile_accuracy: 0.9875 - val_loss: 0.6334 - val_Score_loss: 0.1373 - val_gender_loss: 0.0010 - val_smile_loss: 0.4951 - val_Score_root_mean_squared_error: 0.5906 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9100
# Epoch 51/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0244 - Score_loss: 0.0157 - gender_loss: 0.0029 - smile_loss: 0.0057 - Score_root_mean_squared_error: 0.1776 - gender_accuracy: 0.9987 - smile_accuracy: 1.0000
# Epoch 51: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 349ms/step - loss: 0.0244 - Score_loss: 0.0157 - gender_loss: 0.0029 - smile_loss: 0.0057 - Score_root_mean_squared_error: 0.1776 - gender_accuracy: 0.9987 - smile_accuracy: 1.0000 - val_loss: 0.6306 - val_Score_loss: 0.1431 - val_gender_loss: 0.0015 - val_smile_loss: 0.4860 - val_Score_root_mean_squared_error: 0.6073 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9100
# Epoch 52/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0304 - Score_loss: 0.0147 - gender_loss: 0.0088 - smile_loss: 0.0069 - Score_root_mean_squared_error: 0.1718 - gender_accuracy: 0.9962 - smile_accuracy: 0.9987
# Epoch 52: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0304 - Score_loss: 0.0147 - gender_loss: 0.0088 - smile_loss: 0.0069 - Score_root_mean_squared_error: 0.1718 - gender_accuracy: 0.9962 - smile_accuracy: 0.9987 - val_loss: 0.6611 - val_Score_loss: 0.1403 - val_gender_loss: 0.0155 - val_smile_loss: 0.5052 - val_Score_root_mean_squared_error: 0.5985 - val_gender_accuracy: 0.9900 - val_smile_accuracy: 0.9000
# Epoch 53/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0223 - Score_loss: 0.0104 - gender_loss: 0.0087 - smile_loss: 0.0032 - Score_root_mean_squared_error: 0.1440 - gender_accuracy: 0.9962 - smile_accuracy: 0.9987
# Epoch 53: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 9s 347ms/step - loss: 0.0223 - Score_loss: 0.0104 - gender_loss: 0.0087 - smile_loss: 0.0032 - Score_root_mean_squared_error: 0.1440 - gender_accuracy: 0.9962 - smile_accuracy: 0.9987 - val_loss: 0.7800 - val_Score_loss: 0.1324 - val_gender_loss: 0.0056 - val_smile_loss: 0.6420 - val_Score_root_mean_squared_error: 0.5769 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9000
# Epoch 54/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0455 - Score_loss: 0.0176 - gender_loss: 0.0111 - smile_loss: 0.0168 - Score_root_mean_squared_error: 0.1878 - gender_accuracy: 0.9975 - smile_accuracy: 0.9925
# Epoch 54: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 354ms/step - loss: 0.0455 - Score_loss: 0.0176 - gender_loss: 0.0111 - smile_loss: 0.0168 - Score_root_mean_squared_error: 0.1878 - gender_accuracy: 0.9975 - smile_accuracy: 0.9925 - val_loss: 0.8638 - val_Score_loss: 0.1452 - val_gender_loss: 0.0959 - val_smile_loss: 0.6227 - val_Score_root_mean_squared_error: 0.6087 - val_gender_accuracy: 0.9800 - val_smile_accuracy: 0.8800
# Epoch 55/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0259 - Score_loss: 0.0153 - gender_loss: 0.0017 - smile_loss: 0.0088 - Score_root_mean_squared_error: 0.1752 - gender_accuracy: 1.0000 - smile_accuracy: 0.9975
# Epoch 55: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 343ms/step - loss: 0.0259 - Score_loss: 0.0153 - gender_loss: 0.0017 - smile_loss: 0.0088 - Score_root_mean_squared_error: 0.1752 - gender_accuracy: 1.0000 - smile_accuracy: 0.9975 - val_loss: 0.7557 - val_Score_loss: 0.1497 - val_gender_loss: 0.0212 - val_smile_loss: 0.5849 - val_Score_root_mean_squared_error: 0.6208 - val_gender_accuracy: 0.9800 - val_smile_accuracy: 0.8700
# Epoch 56/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0180 - Score_loss: 0.0143 - gender_loss: 0.0021 - smile_loss: 0.0016 - Score_root_mean_squared_error: 0.1693 - gender_accuracy: 0.9987 - smile_accuracy: 1.0000
# Epoch 56: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 10s 351ms/step - loss: 0.0180 - Score_loss: 0.0143 - gender_loss: 0.0021 - smile_loss: 0.0016 - Score_root_mean_squared_error: 0.1693 - gender_accuracy: 0.9987 - smile_accuracy: 1.0000 - val_loss: 0.7472 - val_Score_loss: 0.1457 - val_gender_loss: 0.0094 - val_smile_loss: 0.5922 - val_Score_root_mean_squared_error: 0.6098 - val_gender_accuracy: 0.9900 - val_smile_accuracy: 0.8900
# Epoch 57/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0178 - Score_loss: 0.0125 - gender_loss: 7.5954e-04 - smile_loss: 0.0046 - Score_root_mean_squared_error: 0.1590 - gender_accuracy: 1.0000 - smile_accuracy: 0.9987
# Epoch 57: val_Score_root_mean_squared_error did not improve from 0.56450
# 25/25 [==============================] - 9s 344ms/step - loss: 0.0178 - Score_loss: 0.0125 - gender_loss: 7.5954e-04 - smile_loss: 0.0046 - Score_root_mean_squared_error: 0.1590 - gender_accuracy: 1.0000 - smile_accuracy: 0.9987 - val_loss: 0.8080 - val_Score_loss: 0.1426 - val_gender_loss: 0.0256 - val_smile_loss: 0.6398 - val_Score_root_mean_squared_error: 0.5928 - val_gender_accuracy: 0.9900 - val_smile_accuracy: 0.9100
# Epoch 58/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0292 - Score_loss: 0.0131 - gender_loss: 0.0013 - smile_loss: 0.0149 - Score_root_mean_squared_error: 0.1618 - gender_accuracy: 1.0000 - smile_accuracy: 0.9925
# Epoch 58: val_Score_root_mean_squared_error improved from 0.56450 to 0.56149, saving model to model_checkpoint.h5
# 25/25 [==============================] - 10s 388ms/step - loss: 0.0292 - Score_loss: 0.0131 - gender_loss: 0.0013 - smile_loss: 0.0149 - Score_root_mean_squared_error: 0.1618 - gender_accuracy: 1.0000 - smile_accuracy: 0.9925 - val_loss: 0.6803 - val_Score_loss: 0.1288 - val_gender_loss: 0.0142 - val_smile_loss: 0.5374 - val_Score_root_mean_squared_error: 0.5615 - val_gender_accuracy: 0.9900 - val_smile_accuracy: 0.9000
# Epoch 59/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0151 - Score_loss: 0.0127 - gender_loss: 0.0013 - smile_loss: 0.0012 - Score_root_mean_squared_error: 0.1591 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000
# Epoch 59: val_Score_root_mean_squared_error did not improve from 0.56149
# 25/25 [==============================] - 10s 351ms/step - loss: 0.0151 - Score_loss: 0.0127 - gender_loss: 0.0013 - smile_loss: 0.0012 - Score_root_mean_squared_error: 0.1591 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000 - val_loss: 0.6415 - val_Score_loss: 0.1353 - val_gender_loss: 0.0215 - val_smile_loss: 0.4847 - val_Score_root_mean_squared_error: 0.5768 - val_gender_accuracy: 0.9800 - val_smile_accuracy: 0.9100
# Epoch 60/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0131 - Score_loss: 0.0101 - gender_loss: 0.0016 - smile_loss: 0.0014 - Score_root_mean_squared_error: 0.1422 - gender_accuracy: 0.9987 - smile_accuracy: 1.0000
# Epoch 60: val_Score_root_mean_squared_error did not improve from 0.56149
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0131 - Score_loss: 0.0101 - gender_loss: 0.0016 - smile_loss: 0.0014 - Score_root_mean_squared_error: 0.1422 - gender_accuracy: 0.9987 - smile_accuracy: 1.0000 - val_loss: 0.6942 - val_Score_loss: 0.1326 - val_gender_loss: 0.0031 - val_smile_loss: 0.5585 - val_Score_root_mean_squared_error: 0.5697 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8900
# Epoch 61/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0152 - Score_loss: 0.0105 - gender_loss: 0.0017 - smile_loss: 0.0030 - Score_root_mean_squared_error: 0.1450 - gender_accuracy: 0.9987 - smile_accuracy: 0.9987
# Epoch 61: val_Score_root_mean_squared_error did not improve from 0.56149
# 25/25 [==============================] - 9s 343ms/step - loss: 0.0152 - Score_loss: 0.0105 - gender_loss: 0.0017 - smile_loss: 0.0030 - Score_root_mean_squared_error: 0.1450 - gender_accuracy: 0.9987 - smile_accuracy: 0.9987 - val_loss: 0.6116 - val_Score_loss: 0.1324 - val_gender_loss: 0.0016 - val_smile_loss: 0.4776 - val_Score_root_mean_squared_error: 0.5700 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9100
# Epoch 62/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0864 - Score_loss: 0.0148 - gender_loss: 0.0185 - smile_loss: 0.0531 - Score_root_mean_squared_error: 0.1720 - gender_accuracy: 0.9937 - smile_accuracy: 0.9837
# Epoch 62: val_Score_root_mean_squared_error did not improve from 0.56149
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0864 - Score_loss: 0.0148 - gender_loss: 0.0185 - smile_loss: 0.0531 - Score_root_mean_squared_error: 0.1720 - gender_accuracy: 0.9937 - smile_accuracy: 0.9837 - val_loss: 0.5689 - val_Score_loss: 0.1407 - val_gender_loss: 0.0187 - val_smile_loss: 0.4095 - val_Score_root_mean_squared_error: 0.5985 - val_gender_accuracy: 0.9900 - val_smile_accuracy: 0.8700
# Epoch 63/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0265 - Score_loss: 0.0125 - gender_loss: 0.0045 - smile_loss: 0.0095 - Score_root_mean_squared_error: 0.1581 - gender_accuracy: 0.9975 - smile_accuracy: 0.9987
# Epoch 63: val_Score_root_mean_squared_error did not improve from 0.56149
# 25/25 [==============================] - 9s 343ms/step - loss: 0.0265 - Score_loss: 0.0125 - gender_loss: 0.0045 - smile_loss: 0.0095 - Score_root_mean_squared_error: 0.1581 - gender_accuracy: 0.9975 - smile_accuracy: 0.9987 - val_loss: 0.7670 - val_Score_loss: 0.1468 - val_gender_loss: 0.0025 - val_smile_loss: 0.6177 - val_Score_root_mean_squared_error: 0.6099 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8900
# Epoch 64/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0384 - Score_loss: 0.0129 - gender_loss: 0.0137 - smile_loss: 0.0119 - Score_root_mean_squared_error: 0.1607 - gender_accuracy: 0.9962 - smile_accuracy: 0.9950
# Epoch 64: val_Score_root_mean_squared_error did not improve from 0.56149
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0384 - Score_loss: 0.0129 - gender_loss: 0.0137 - smile_loss: 0.0119 - Score_root_mean_squared_error: 0.1607 - gender_accuracy: 0.9962 - smile_accuracy: 0.9950 - val_loss: 0.7758 - val_Score_loss: 0.1381 - val_gender_loss: 0.0687 - val_smile_loss: 0.5690 - val_Score_root_mean_squared_error: 0.5897 - val_gender_accuracy: 0.9900 - val_smile_accuracy: 0.9000
# Epoch 65/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0416 - Score_loss: 0.0137 - gender_loss: 0.0063 - smile_loss: 0.0216 - Score_root_mean_squared_error: 0.1660 - gender_accuracy: 0.9962 - smile_accuracy: 0.9912
# Epoch 65: val_Score_root_mean_squared_error did not improve from 0.56149
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0416 - Score_loss: 0.0137 - gender_loss: 0.0063 - smile_loss: 0.0216 - Score_root_mean_squared_error: 0.1660 - gender_accuracy: 0.9962 - smile_accuracy: 0.9912 - val_loss: 1.0617 - val_Score_loss: 0.1424 - val_gender_loss: 0.0271 - val_smile_loss: 0.8921 - val_Score_root_mean_squared_error: 0.6035 - val_gender_accuracy: 0.9800 - val_smile_accuracy: 0.8700
# ...
# 25/25 [==============================] - 10s 351ms/step - loss: 0.0224 - Score_loss: 0.0137 - gender_loss: 3.5700e-04 - smile_loss: 0.0083 - Score_root_mean_squared_error: 0.1654 - gender_accuracy: 1.0000 - smile_accuracy: 0.9975 - val_loss: 0.5739 - val_Score_loss: 0.1357 - val_gender_loss: 0.0013 - val_smile_loss: 0.4369 - val_Score_root_mean_squared_error: 0.5720 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8900
# Epoch 80/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0308 - Score_loss: 0.0143 - gender_loss: 0.0071 - smile_loss: 0.0094 - Score_root_mean_squared_error: 0.1695 - gender_accuracy: 0.9962 - smile_accuracy: 0.9987
# Epoch 80: val_Score_root_mean_squared_error did not improve from 0.55190
# 25/25 [==============================] - 9s 351ms/step - loss: 0.0308 - Score_loss: 0.0143 - gender_loss: 0.0071 - smile_loss: 0.0094 - Score_root_mean_squared_error: 0.1695 - gender_accuracy: 0.9962 - smile_accuracy: 0.9987 - val_loss: 0.4426 - val_Score_loss: 0.1259 - val_gender_loss: 0.0150 - val_smile_loss: 0.3017 - val_Score_root_mean_squared_error: 0.5525 - val_gender_accuracy: 0.9900 - val_smile_accuracy: 0.9100
# Epoch 81/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0290 - Score_loss: 0.0120 - gender_loss: 0.0090 - smile_loss: 0.0080 - Score_root_mean_squared_error: 0.1550 - gender_accuracy: 0.9975 - smile_accuracy: 0.9962
# Epoch 81: val_Score_root_mean_squared_error did not improve from 0.55190
# 25/25 [==============================] - 9s 344ms/step - loss: 0.0290 - Score_loss: 0.0120 - gender_loss: 0.0090 - smile_loss: 0.0080 - Score_root_mean_squared_error: 0.1550 - gender_accuracy: 0.9975 - smile_accuracy: 0.9962 - val_loss: 0.5465 - val_Score_loss: 0.1281 - val_gender_loss: 0.0728 - val_smile_loss: 0.3455 - val_Score_root_mean_squared_error: 0.5615 - val_gender_accuracy: 0.9700 - val_smile_accuracy: 0.8900
# Epoch 82/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1123 - Score_loss: 0.0198 - gender_loss: 0.0669 - smile_loss: 0.0255 - Score_root_mean_squared_error: 0.2010 - gender_accuracy: 0.9775 - smile_accuracy: 0.9937
# Epoch 82: val_Score_root_mean_squared_error did not improve from 0.55190
# 25/25 [==============================] - 10s 352ms/step - loss: 0.1123 - Score_loss: 0.0198 - gender_loss: 0.0669 - smile_loss: 0.0255 - Score_root_mean_squared_error: 0.2010 - gender_accuracy: 0.9775 - smile_accuracy: 0.9937 - val_loss: 0.6234 - val_Score_loss: 0.1282 - val_gender_loss: 0.0646 - val_smile_loss: 0.4306 - val_Score_root_mean_squared_error: 0.5634 - val_gender_accuracy: 0.9900 - val_smile_accuracy: 0.8600
# Epoch 83/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0466 - Score_loss: 0.0176 - gender_loss: 0.0175 - smile_loss: 0.0116 - Score_root_mean_squared_error: 0.1880 - gender_accuracy: 0.9912 - smile_accuracy: 0.9962
# Epoch 83: val_Score_root_mean_squared_error did not improve from 0.55190
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0466 - Score_loss: 0.0176 - gender_loss: 0.0175 - smile_loss: 0.0116 - Score_root_mean_squared_error: 0.1880 - gender_accuracy: 0.9912 - smile_accuracy: 0.9962 - val_loss: 0.7688 - val_Score_loss: 0.1328 - val_gender_loss: 0.0052 - val_smile_loss: 0.6308 - val_Score_root_mean_squared_error: 0.5863 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8600
# Epoch 84/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1096 - Score_loss: 0.0204 - gender_loss: 0.0155 - smile_loss: 0.0737 - Score_root_mean_squared_error: 0.2039 - gender_accuracy: 0.9950 - smile_accuracy: 0.9762
# Epoch 84: val_Score_root_mean_squared_error did not improve from 0.55190
# 25/25 [==============================] - 10s 353ms/step - loss: 0.1096 - Score_loss: 0.0204 - gender_loss: 0.0155 - smile_loss: 0.0737 - Score_root_mean_squared_error: 0.2039 - gender_accuracy: 0.9950 - smile_accuracy: 0.9762 - val_loss: 0.5805 - val_Score_loss: 0.1282 - val_gender_loss: 0.0021 - val_smile_loss: 0.4502 - val_Score_root_mean_squared_error: 0.5704 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8600
# Epoch 85/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0398 - Score_loss: 0.0177 - gender_loss: 0.0081 - smile_loss: 0.0140 - Score_root_mean_squared_error: 0.1885 - gender_accuracy: 0.9975 - smile_accuracy: 0.9962
# Epoch 85: val_Score_root_mean_squared_error did not improve from 0.55190
# 25/25 [==============================] - 10s 350ms/step - loss: 0.0398 - Score_loss: 0.0177 - gender_loss: 0.0081 - smile_loss: 0.0140 - Score_root_mean_squared_error: 0.1885 - gender_accuracy: 0.9975 - smile_accuracy: 0.9962 - val_loss: 0.4800 - val_Score_loss: 0.1372 - val_gender_loss: 0.0095 - val_smile_loss: 0.3333 - val_Score_root_mean_squared_error: 0.5908 - val_gender_accuracy: 0.9900 - val_smile_accuracy: 0.9200
# Epoch 86/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0260 - Score_loss: 0.0154 - gender_loss: 0.0067 - smile_loss: 0.0038 - Score_root_mean_squared_error: 0.1757 - gender_accuracy: 0.9987 - smile_accuracy: 0.9987
# Epoch 86: val_Score_root_mean_squared_error did not improve from 0.55190
# 25/25 [==============================] - 10s 351ms/step - loss: 0.0260 - Score_loss: 0.0154 - gender_loss: 0.0067 - smile_loss: 0.0038 - Score_root_mean_squared_error: 0.1757 - gender_accuracy: 0.9987 - smile_accuracy: 0.9987 - val_loss: 0.4805 - val_Score_loss: 0.1292 - val_gender_loss: 0.0051 - val_smile_loss: 0.3462 - val_Score_root_mean_squared_error: 0.5725 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9300
# Epoch 87/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0195 - Score_loss: 0.0129 - gender_loss: 4.2429e-04 - smile_loss: 0.0062 - Score_root_mean_squared_error: 0.1605 - gender_accuracy: 1.0000 - smile_accuracy: 0.9987
# Epoch 87: val_Score_root_mean_squared_error did not improve from 0.55190
# 25/25 [==============================] - 10s 344ms/step - loss: 0.0195 - Score_loss: 0.0129 - gender_loss: 4.2429e-04 - smile_loss: 0.0062 - Score_root_mean_squared_error: 0.1605 - gender_accuracy: 1.0000 - smile_accuracy: 0.9987 - val_loss: 0.6758 - val_Score_loss: 0.1374 - val_gender_loss: 0.0033 - val_smile_loss: 0.5351 - val_Score_root_mean_squared_error: 0.5931 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8900
# Epoch 88/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0146 - Score_loss: 0.0109 - gender_loss: 6.6884e-04 - smile_loss: 0.0031 - Score_root_mean_squared_error: 0.1476 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000
# Epoch 88: val_Score_root_mean_squared_error improved from 0.55190 to 0.55098, saving model to model_checkpoint.h5
# 25/25 [==============================] - 11s 388ms/step - loss: 0.0146 - Score_loss: 0.0109 - gender_loss: 6.6884e-04 - smile_loss: 0.0031 - Score_root_mean_squared_error: 0.1476 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000 - val_loss: 0.4550 - val_Score_loss: 0.1213 - val_gender_loss: 0.0043 - val_smile_loss: 0.3294 - val_Score_root_mean_squared_error: 0.5510 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9100
# Epoch 89/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0116 - Score_loss: 0.0103 - gender_loss: 2.3230e-04 - smile_loss: 0.0011 - Score_root_mean_squared_error: 0.1435 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000
# Epoch 89: val_Score_root_mean_squared_error did not improve from 0.55098
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0116 - Score_loss: 0.0103 - gender_loss: 2.3230e-04 - smile_loss: 0.0011 - Score_root_mean_squared_error: 0.1435 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000 - val_loss: 0.4731 - val_Score_loss: 0.1242 - val_gender_loss: 0.0062 - val_smile_loss: 0.3427 - val_Score_root_mean_squared_error: 0.5550 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9100
# Epoch 90/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0145 - Score_loss: 0.0104 - gender_loss: 0.0016 - smile_loss: 0.0025 - Score_root_mean_squared_error: 0.1443 - gender_accuracy: 1.0000 - smile_accuracy: 0.9987
# Epoch 90: val_Score_root_mean_squared_error did not improve from 0.55098
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0145 - Score_loss: 0.0104 - gender_loss: 0.0016 - smile_loss: 0.0025 - Score_root_mean_squared_error: 0.1443 - gender_accuracy: 1.0000 - smile_accuracy: 0.9987 - val_loss: 0.4512 - val_Score_loss: 0.1220 - val_gender_loss: 0.0033 - val_smile_loss: 0.3259 - val_Score_root_mean_squared_error: 0.5521 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9300
# Epoch 91/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0184 - Score_loss: 0.0089 - gender_loss: 1.6227e-04 - smile_loss: 0.0094 - Score_root_mean_squared_error: 0.1331 - gender_accuracy: 1.0000 - smile_accuracy: 0.9950
# Epoch 91: val_Score_root_mean_squared_error improved from 0.55098 to 0.54705, saving model to model_checkpoint.h5
# 25/25 [==============================] - 11s 388ms/step - loss: 0.0184 - Score_loss: 0.0089 - gender_loss: 1.6227e-04 - smile_loss: 0.0094 - Score_root_mean_squared_error: 0.1331 - gender_accuracy: 1.0000 - smile_accuracy: 0.9950 - val_loss: 0.5977 - val_Score_loss: 0.1220 - val_gender_loss: 0.0013 - val_smile_loss: 0.4743 - val_Score_root_mean_squared_error: 0.5471 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9100
# Epoch 92/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0334 - Score_loss: 0.0130 - gender_loss: 0.0021 - smile_loss: 0.0184 - Score_root_mean_squared_error: 0.1610 - gender_accuracy: 0.9987 - smile_accuracy: 0.9950
# Epoch 92: val_Score_root_mean_squared_error did not improve from 0.54705
# 25/25 [==============================] - 10s 351ms/step - loss: 0.0334 - Score_loss: 0.0130 - gender_loss: 0.0021 - smile_loss: 0.0184 - Score_root_mean_squared_error: 0.1610 - gender_accuracy: 0.9987 - smile_accuracy: 0.9950 - val_loss: 0.6666 - val_Score_loss: 0.1247 - val_gender_loss: 0.0016 - val_smile_loss: 0.5403 - val_Score_root_mean_squared_error: 0.5622 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8800
# Epoch 93/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0276 - Score_loss: 0.0120 - gender_loss: 0.0028 - smile_loss: 0.0127 - Score_root_mean_squared_error: 0.1562 - gender_accuracy: 0.9987 - smile_accuracy: 0.9950
# Epoch 93: val_Score_root_mean_squared_error did not improve from 0.54705
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0276 - Score_loss: 0.0120 - gender_loss: 0.0028 - smile_loss: 0.0127 - Score_root_mean_squared_error: 0.1562 - gender_accuracy: 0.9987 - smile_accuracy: 0.9950 - val_loss: 0.5190 - val_Score_loss: 0.1209 - val_gender_loss: 0.0246 - val_smile_loss: 0.3735 - val_Score_root_mean_squared_error: 0.5477 - val_gender_accuracy: 0.9900 - val_smile_accuracy: 0.9100
# Epoch 94/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0151 - Score_loss: 0.0135 - gender_loss: 2.6945e-04 - smile_loss: 0.0013 - Score_root_mean_squared_error: 0.1649 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000
# Epoch 94: val_Score_root_mean_squared_error did not improve from 0.54705
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0151 - Score_loss: 0.0135 - gender_loss: 2.6945e-04 - smile_loss: 0.0013 - Score_root_mean_squared_error: 0.1649 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000 - val_loss: 0.5738 - val_Score_loss: 0.1245 - val_gender_loss: 0.0010 - val_smile_loss: 0.4483 - val_Score_root_mean_squared_error: 0.5585 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8900
# Epoch 95/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0125 - Score_loss: 0.0108 - gender_loss: 3.5870e-04 - smile_loss: 0.0013 - Score_root_mean_squared_error: 0.1474 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000
# Epoch 95: val_Score_root_mean_squared_error did not improve from 0.54705
# 25/25 [==============================] - 10s 344ms/step - loss: 0.0125 - Score_loss: 0.0108 - gender_loss: 3.5870e-04 - smile_loss: 0.0013 - Score_root_mean_squared_error: 0.1474 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000 - val_loss: 0.5274 - val_Score_loss: 0.1219 - val_gender_loss: 0.0013 - val_smile_loss: 0.4043 - val_Score_root_mean_squared_error: 0.5480 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.8900
# Epoch 96/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0124 - Score_loss: 0.0113 - gender_loss: 1.8277e-04 - smile_loss: 8.8001e-04 - Score_root_mean_squared_error: 0.1505 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000
# Epoch 96: val_Score_root_mean_squared_error did not improve from 0.54705
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0124 - Score_loss: 0.0113 - gender_loss: 1.8277e-04 - smile_loss: 8.8001e-04 - Score_root_mean_squared_error: 0.1505 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000 - val_loss: 0.5250 - val_Score_loss: 0.1233 - val_gender_loss: 0.0015 - val_smile_loss: 0.4003 - val_Score_root_mean_squared_error: 0.5527 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9100
# Epoch 97/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0095 - Score_loss: 0.0089 - gender_loss: 2.2209e-04 - smile_loss: 3.9149e-04 - Score_root_mean_squared_error: 0.1337 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000
# Epoch 97: val_Score_root_mean_squared_error did not improve from 0.54705
# 25/25 [==============================] - 9s 343ms/step - loss: 0.0095 - Score_loss: 0.0089 - gender_loss: 2.2209e-04 - smile_loss: 3.9149e-04 - Score_root_mean_squared_error: 0.1337 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000 - val_loss: 0.5217 - val_Score_loss: 0.1271 - val_gender_loss: 5.8021e-04 - val_smile_loss: 0.3941 - val_Score_root_mean_squared_error: 0.5642 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9100
# Epoch 98/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0097 - Score_loss: 0.0094 - gender_loss: 1.1935e-04 - smile_loss: 2.0207e-04 - Score_root_mean_squared_error: 0.1374 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000
# Epoch 98: val_Score_root_mean_squared_error improved from 0.54705 to 0.53722, saving model to model_checkpoint.h5
# 25/25 [==============================] - 10s 389ms/step - loss: 0.0097 - Score_loss: 0.0094 - gender_loss: 1.1935e-04 - smile_loss: 2.0207e-04 - Score_root_mean_squared_error: 0.1374 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000 - val_loss: 0.5030 - val_Score_loss: 0.1171 - val_gender_loss: 0.0016 - val_smile_loss: 0.3843 - val_Score_root_mean_squared_error: 0.5372 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9100
# Epoch 99/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0094 - Score_loss: 0.0076 - gender_loss: 1.0763e-04 - smile_loss: 0.0017 - Score_root_mean_squared_error: 0.1232 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000
# Epoch 99: val_Score_root_mean_squared_error did not improve from 0.53722
# 25/25 [==============================] - 10s 352ms/step - loss: 0.0094 - Score_loss: 0.0076 - gender_loss: 1.0763e-04 - smile_loss: 0.0017 - Score_root_mean_squared_error: 0.1232 - gender_accuracy: 1.0000 - smile_accuracy: 1.0000 - val_loss: 0.5852 - val_Score_loss: 0.1219 - val_gender_loss: 0.0014 - val_smile_loss: 0.4619 - val_Score_root_mean_squared_error: 0.5453 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9000
# Epoch 100/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0196 - Score_loss: 0.0074 - gender_loss: 1.2327e-04 - smile_loss: 0.0121 - Score_root_mean_squared_error: 0.1213 - gender_accuracy: 1.0000 - smile_accuracy: 0.9975
# Epoch 100: val_Score_root_mean_squared_error did not improve from 0.53722
# 25/25 [==============================] - 10s 353ms/step - loss: 0.0196 - Score_loss: 0.0074 - gender_loss: 1.2327e-04 - smile_loss: 0.0121 - Score_root_mean_squared_error: 0.1213 - gender_accuracy: 1.0000 - smile_accuracy: 0.9975 - val_loss: 0.6104 - val_Score_loss: 0.1176 - val_gender_loss: 0.0017 - val_smile_loss: 0.4911 - val_Score_root_mean_squared_error: 0.5396 - val_gender_accuracy: 1.0000 - val_smile_accuracy: 0.9100

# %%
model.load_weights('model_checkpoint.h5')
model.evaluate(test_dataset)
# Out:
# 4/4 [==============================] - 0s 55ms/step - loss: 0.5571 - Score_loss: 0.1091 - gender_loss: 0.0711 - smile_loss: 0.3768 - Score_root_mean_squared_error: 0.5262 - gender_accuracy: 0.9800 - smile_accuracy: 0.9000
# [0.5570784211158752,
#  0.10909557342529297,
#  0.07114336639642715,
#  0.3768394887447357,
#  0.5262042284011841,
#  0.9800000190734863,
#  0.8999999761581421]

# %%
y_pred = model.predict(test_dataset)[0].flatten()
# Out:
# 4/4 [==============================] - 2s 62ms/step

# %%
y_true = df_test['final rating'].values

# %%
rmse=tf.keras.metrics.RootMeanSquaredError()(y_true,y_pred)
mae=tf.keras.metrics.MeanAbsoluteError()(y_true,y_pred)

# %%
# Calculate the Pearson correlation coefficient matrix
correlation_matrix = np.corrcoef(y_true, y_pred)

# Extract the Pearson correlation coefficient
pearson_corr = correlation_matrix[0, 1]

print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"PC: {pearson_corr:.4f}")
# Out:
# RMSE: 0.5262
# MAE: 0.3997
# PC: 0.5548

# %%
# Plotting y_true vs y_pred
plt.figure(figsize=(8, 6))
plt.scatter(y_pred,y_true, marker='+', color='blue', alpha=0.6, label='Actual vs. Predicted')
plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], color='red', linestyle='--', linewidth=2, label='Ideal Line')

# Add labels and title
plt.xlabel('Predicted Beauty Score')
plt.ylabel('Actual Beauty Score')
plt.legend()
plt.grid(True)
plt.savefig('effenenet.svg', dpi=600,bbox_inches='tight', pad_inches=0)
